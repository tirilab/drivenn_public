# %%
from utility import *

from collections import Counter
from scipy.stats import ks_2samp

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import random
import pandas as pd
import seaborn as sns
import collections
import json as json

# %matplotlib inline

# %%
# df display side by side

from IPython.display import display_html
from itertools import chain,cycle
def display_side_by_side(*args,titles=cycle([''])):
    html_str=''
    for df,title in zip(args, chain(titles,cycle(['</br>'])) ):
        html_str+='<th style="text-align:center"><td style="vertical-align:top">'
        html_str+=f'<h2 style="text-align: center;">{title}</h2>'
        html_str+=df.to_html().replace('table','table style="display:inline"')
        html_str+='</td></th>'
    display_html(html_str,raw=True)

# %%
combo2stitch, combo2se, se2name = load_combo_se(fname='../data/decagon_data/bio-decagon-combo.csv')
net, node2idx = load_ppi(fname='../data/decagon_data/bio-decagon-ppi.csv')
stitch2se, se2name_mono = load_mono_se(fname='../data/decagon_data/bio-decagon-mono.csv')
stitch2proteins = load_targets(fname='../data/decagon_data/bio-decagon-targets.csv')
se2class, se2name_class = load_categories(fname='../data/decagon_data/bio-decagon-effectcategories.csv')
se2name.update(se2name_mono)
se2name.update(se2name_class)
# Out:
# Reading: ../data/decagon_data/bio-decagon-combo.csv
# Drug combinations: 63473 Side effects: 1317
# Drug-drug interactions: 4649441
# Reading: ../data/decagon_data/bio-decagon-ppi.csv
# Edges: 715612
# Nodes: 19081
# Reading: ../data/decagon_data/bio-decagon-mono.csv
# Reading: ../data/decagon_data/bio-decagon-targets.csv
# Reading: ../data/decagon_data/bio-decagon-effectcategories.csv

# %%
cvd_df = pd.read_csv("../data/cvd_df.csv")

# %%
# summary of original dataset

# drugs with protein info
drugs_w_protein = list(stitch2proteins.keys())
print("drug proteins: " + str(len(drugs_w_protein)))

# drugs with individual SE info 
drugs_w_indiv_se = list(stitch2se.keys())
print("indiv drugs: " + str(len(drugs_w_indiv_se)))

# drugs with combo SE info
combo_drugs = np.unique(np.array([i for pair in list(combo2stitch.values()) for i in pair]))
print("combo drugs: " + str(len(combo_drugs)))

# total drugs
total_drugs = []
[total_drugs.extend(li) for li in (drugs_w_protein, drugs_w_indiv_se, combo_drugs)]
total_drugs = np.array(total_drugs)
total_drugs = np.unique(np.array(total_drugs))
print("total unique drugs: " + str(len(total_drugs)))
# Out:
# drug proteins: 284
# indiv drugs: 639
# combo drugs: 645
# total unique drugs: 645

# %% [markdown]
# # Preliminary EDA

# %% [markdown]
# ### Top 10 SE Classes

# %%
# top 10 types of side effect classes

se_classes = pd.DataFrame({"se_code": list(se2class.keys()),
             "se_class": list(se2class.values())})

se_names = pd.DataFrame({"se_code": list(se2name.keys()),
                        "se_name": list(se2name.values())})

se_classes.groupby("se_class", as_index=False) \
    .agg({"se_code": len}) \
    .sort_values("se_code", ascending=False) \
    .head(10) \
    .plot.barh(x="se_class", title='Top 10 SE Classes Total', color="darkturquoise");

# %% [markdown]
# ### Top 10 Side Effects for Individual Drugs

# %%
# function that returns the top n single side effects of the drugs given

def get_top_se(drug_ids, n = 10, df = stitch2se):
    single_se = []
    for drug_id in drug_ids:
        for i_se in df[drug_id]:
            single_se.append(i_se)
    
    single_se_df = pd.DataFrame({"se": single_se})
    single_se_df = pd.merge(single_se_df, se_names, how = "left", left_on = "se", right_on = "se_code")
    top_ten = single_se_df.groupby("se_name", as_index=False) \
        .agg({"se": len}) \
        .sort_values("se", ascending=False) \
        .head(n)
    
    return top_ten

# %%
# top ten SEs for all drugs
top_single_se_all = get_top_se(stitch2se.keys())

# top ten SEs for CVD drugs
top_single_se_cvd = get_top_se(cvd_df.total_drugs)

display_side_by_side(top_single_se_all, top_single_se_cvd, titles=["All Drugs Top Single SEs", "CVD Drugs Top Single SEs"])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">All Drugs Top Single SEs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>se_name</th>
#       <th>se</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>4815</th>
#       <td>general physical health deterioration</td>
#       <td>301</td>
#     </tr>
#     <tr>
#       <th>5316</th>
#       <td>hypoaesthesia</td>
#       <td>279</td>
#     </tr>
#     <tr>
#       <th>6335</th>
#       <td>mental status changes</td>
#       <td>278</td>
#     </tr>
#     <tr>
#       <th>8992</th>
#       <td>tooth extraction</td>
#       <td>276</td>
#     </tr>
#     <tr>
#       <th>4160</th>
#       <td>emotional distress</td>
#       <td>275</td>
#     </tr>
#     <tr>
#       <th>1579</th>
#       <td>alanine aminotransferase increased</td>
#       <td>273</td>
#     </tr>
#     <tr>
#       <th>3360</th>
#       <td>condition aggravated</td>
#       <td>270</td>
#     </tr>
#     <tr>
#       <th>7562</th>
#       <td>pollakiuria</td>
#       <td>267</td>
#     </tr>
#     <tr>
#       <th>8671</th>
#       <td>staphylococcal infection</td>
#       <td>266</td>
#     </tr>
#     <tr>
#       <th>2452</th>
#       <td>blood creatinine increased</td>
#       <td>263</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">CVD Drugs Top Single SEs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>se_name</th>
#       <th>se</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>415</th>
#       <td>blood creatinine increased</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>461</th>
#       <td>blood urea increased</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>1197</th>
#       <td>left ventricular dysfunction</td>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>826</th>
#       <td>emotional distress</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>102</th>
#       <td>Hyperhidrosis</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>1120</th>
#       <td>infusion site mobility decreased</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>186</th>
#       <td>Visual impairment</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>671</th>
#       <td>coronary artery occlusion</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>471</th>
#       <td>bone disorder</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>445</th>
#       <td>blood potassium increased</td>
#       <td>8</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %%
# overlap between top 10 SEs
pd.merge(top_single_se_all, top_single_se_cvd, how="inner", on="se_name")
# Out:
#                       se_name  se_x  se_y
# 0          emotional distress   275     9
# 1  blood creatinine increased   263    12

# %% [markdown]
# ### Top 10 Side Effects Per Drug Combination

# %%
# to help filter top ten SEs for any combination of drugs containing at least one CVD drug and 2 CVD drugs

one_cvd = []
two_cvd = []

for key in list(combo2se.keys()):
    drugs = key.split("_")
    if drugs[0] in list(cvd_df.total_drugs):
        one_cvd.append(key)
        if drugs[1] in list(cvd_df.total_drugs):
            two_cvd.append(key)
    elif drugs[1] in list(cvd_df.total_drugs):
        one_cvd.append(key)

# %%
print("total number of drug-drug pairs: " + str(len(combo2se.keys())))
print("total number of drug-drug pairs with at least one cvd drug: " + str(len(one_cvd)))
print("total number of drug-drug pairs with 2 cvd drugs: " + str(len(two_cvd)))
# Out:
# total number of drug-drug pairs: 63473
# total number of drug-drug pairs with at least one cvd drug: 5206
# total number of drug-drug pairs with 2 cvd drugs: 78

# %%
pd.DataFrame({"drug_pairs": one_cvd}).to_csv("../data/one_cvd.csv")
pd.DataFrame({"drug_pairs": two_cvd}).to_csv("../data/two_cvd.csv")

# %%
# top ten SEs for any combination of drugs

top_combo_se_all = get_top_se(combo2se.keys(), df = combo2se)

top_combo_se_one = get_top_se(one_cvd, df = combo2se)

top_combo_se_two = get_top_se(two_cvd, df = combo2se)

# %%
# display dfs 

display_side_by_side(top_combo_se_all, \
                     top_combo_se_one, \
                     top_combo_se_two, \
                     titles=["All Drug Pairs Top SEs", ">= 1 CVD Drug Top SEs", "2 CVD Drugs Top SEs"])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">All Drug Pairs Top SEs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>se_name</th>
#       <th>se</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>373</th>
#       <td>arterial pressure NOS decreased</td>
#       <td>28568</td>
#     </tr>
#     <tr>
#       <th>342</th>
#       <td>anaemia</td>
#       <td>27006</td>
#     </tr>
#     <tr>
#       <th>102</th>
#       <td>Difficulty breathing</td>
#       <td>26037</td>
#     </tr>
#     <tr>
#       <th>1006</th>
#       <td>nausea</td>
#       <td>25190</td>
#     </tr>
#     <tr>
#       <th>1015</th>
#       <td>neumonia</td>
#       <td>24430</td>
#     </tr>
#     <tr>
#       <th>132</th>
#       <td>Fatigue</td>
#       <td>24260</td>
#     </tr>
#     <tr>
#       <th>210</th>
#       <td>Pain</td>
#       <td>23894</td>
#     </tr>
#     <tr>
#       <th>603</th>
#       <td>diarrhea</td>
#       <td>23848</td>
#     </tr>
#     <tr>
#       <th>384</th>
#       <td>asthenia</td>
#       <td>23515</td>
#     </tr>
#     <tr>
#       <th>652</th>
#       <td>emesis</td>
#       <td>23043</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">>= 1 CVD Drug Top SEs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>se_name</th>
#       <th>se</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>361</th>
#       <td>arterial pressure NOS decreased</td>
#       <td>2471</td>
#     </tr>
#     <tr>
#       <th>332</th>
#       <td>anaemia</td>
#       <td>2461</td>
#     </tr>
#     <tr>
#       <th>99</th>
#       <td>Difficulty breathing</td>
#       <td>2443</td>
#     </tr>
#     <tr>
#       <th>983</th>
#       <td>neumonia</td>
#       <td>2114</td>
#     </tr>
#     <tr>
#       <th>974</th>
#       <td>nausea</td>
#       <td>2057</td>
#     </tr>
#     <tr>
#       <th>206</th>
#       <td>Pain</td>
#       <td>1999</td>
#     </tr>
#     <tr>
#       <th>294</th>
#       <td>acute kidney failure</td>
#       <td>1981</td>
#     </tr>
#     <tr>
#       <th>68</th>
#       <td>Cardiac decompensation</td>
#       <td>1966</td>
#     </tr>
#     <tr>
#       <th>585</th>
#       <td>diarrhea</td>
#       <td>1965</td>
#     </tr>
#     <tr>
#       <th>627</th>
#       <td>edema extremities</td>
#       <td>1964</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">2 CVD Drugs Top SEs</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>se_name</th>
#       <th>se</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>242</th>
#       <td>acute kidney failure</td>
#       <td>47</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>AFIB</td>
#       <td>44</td>
#     </tr>
#     <tr>
#       <th>301</th>
#       <td>arterial pressure NOS decreased</td>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>726</th>
#       <td>kidney failure</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>518</th>
#       <td>edema extremities</td>
#       <td>41</td>
#     </tr>
#     <tr>
#       <th>918</th>
#       <td>rhabdomyolysis</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>275</th>
#       <td>anaemia</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>63</th>
#       <td>Cardiac decompensation</td>
#       <td>40</td>
#     </tr>
#     <tr>
#       <th>304</th>
#       <td>arteriosclerotic heart disease</td>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>133</th>
#       <td>High blood pressure</td>
#       <td>37</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %%
# overlap between top 10 all drugs and at least 1 CVD drug
all_one = pd.merge(top_combo_se_all, top_combo_se_one, how="inner", on="se_name")

# overlap between top 10 all drugs and 2 CVD drug
all_two = pd.merge(top_combo_se_all, top_combo_se_two, how="inner", on="se_name")

# overlap between at least 1 CVD drug and 2 cvd drug
one_two = pd.merge(top_combo_se_two, top_combo_se_one, how="inner", on="se_name")

display_side_by_side(all_one, \
                     all_two, \
                     one_two, \
                     titles=["Overlap: All vs >= 1", "Overlap: All vs 2", "Overlap: >= 1 vs 2"])
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Overlap: All vs >= 1</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>se_name</th>
#       <th>se_x</th>
#       <th>se_y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>arterial pressure NOS decreased</td>
#       <td>28568</td>
#       <td>2471</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>anaemia</td>
#       <td>27006</td>
#       <td>2461</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Difficulty breathing</td>
#       <td>26037</td>
#       <td>2443</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>nausea</td>
#       <td>25190</td>
#       <td>2057</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>neumonia</td>
#       <td>24430</td>
#       <td>2114</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Pain</td>
#       <td>23894</td>
#       <td>1999</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>diarrhea</td>
#       <td>23848</td>
#       <td>1965</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Overlap: All vs 2</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>se_name</th>
#       <th>se_x</th>
#       <th>se_y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>arterial pressure NOS decreased</td>
#       <td>28568</td>
#       <td>43</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>anaemia</td>
#       <td>27006</td>
#       <td>40</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th><th style="text-align:center"><td style="vertical-align:top"><h2 style="text-align: center;">Overlap: >= 1 vs 2</h2><table style="display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>se_name</th>
#       <th>se_x</th>
#       <th>se_y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>acute kidney failure</td>
#       <td>47</td>
#       <td>1981</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>arterial pressure NOS decreased</td>
#       <td>43</td>
#       <td>2471</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>edema extremities</td>
#       <td>41</td>
#       <td>1964</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>anaemia</td>
#       <td>40</td>
#       <td>2461</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Cardiac decompensation</td>
#       <td>40</td>
#       <td>1966</td>
#     </tr>
#   </tbody>
# </table style="display:inline"></td></th>

# %% [markdown]
# ### Cardiovascular Side Effects for all Drugs

# %%
# look into cardiovascular side effects for all drugs

pd.merge(se_classes[se_classes["se_class"] == "cardiovascular system disease"], \
         se_names, on = "se_code", how = "inner")
# Out:
#      se_code                       se_class                    se_name
# 0   C0032807  cardiovascular system disease   Post thrombotic syndrome
# 1   C0003486  cardiovascular system disease            aortic aneurysm
# 2   C0038454  cardiovascular system disease                   apoplexy
# 3   C0027051  cardiovascular system disease               heart attack
# 4   C0034072  cardiovascular system disease              Cor pulmonale
# ..       ...                            ...                        ...
# 56  C0026267  cardiovascular system disease      mitral valve prolapse
# 57  C0018818  cardiovascular system disease  ventricular septal defect
# 58  C0018817  cardiovascular system disease       atrial septal defect
# 59  C0031039  cardiovascular system disease       pericardial effusion
# 60  C0031036  cardiovascular system disease       periarteritis nodosa
#
# [61 rows x 3 columns]

# %% [markdown]
# ### Median Number of Side Effects Per Drug Combination

# %%
def plot_distribution(dist, ax = 0, title="", x_label="", y_label="", file_name=None):
    sns.set_context("paper", font_scale=2)
    sns.set_style('ticks')
    sns.set_style({"xtick.direction": "in", "ytick.direction": "in"})
    sns.distplot(dist, kde=False, color=sns.xkcd_rgb['cornflower'], bins=20, hist_kws={"alpha" : 1}, ax = axs[ax])
    plt.savefig("plots/" + title + '.png')
    axs[ax].set(xlabel=x_label,
               ylabel=y_label,
               title=title);

# %%
fig, axs = plt.subplots(ncols = 3, figsize=(20, 5))


count = 0
for val_list, title in zip([combo2se, one_cvd, two_cvd], ["All Drug Pairs", ">= 1 CVD Drug in Pair", "2 CVD Drug Pair"]):
    distribution_combos = [len(combo2se[combo]) for combo in val_list]
    med = np.median(distribution_combos)
    print(f'Median number of side effects per {title}: {med}')
    plot_distribution(distribution_combos, count, title, "Number of Side Effects", "Number of Drug Combinations")
    count += 1
# Out:
# Median number of side effects per All Drug Pairs: 53.0
# /var/folders/t8/sjfdkz0d3d16blq9dcc9z61r0000gn/T/ipykernel_8616/1064932916.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dist, kde=False, color=sns.xkcd_rgb['cornflower'], bins=20, hist_kws={"alpha" : 1}, ax = axs[ax])
# Median number of side effects per >= 1 CVD Drug in Pair: 65.0
# Median number of side effects per 2 CVD Drug Pair: 124.5
